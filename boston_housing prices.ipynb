# %%
import tensorflow as tf
from tensorflow.keras.datasets import boston_housing
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
#Load Boston Housing prices dataset
(x_train,y_train),(x_test,y_test) = boston_housing.load_data()

print(y_train[:6])
# Out:
# [15.2 42.3 50.  21.1 17.7 18.5]

# %%
#in-built layers
model = Sequential([
    Flatten(input_shape = (13,)),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation = 'linear')
])
model.summary()

model.compile(optimizer = 'adam',loss = 'mse',metrics = ['mae'])
model.fit(x_train,y_train,epochs = 50, batch_size =32, validation_split = 0.2)
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_20 (Flatten)                 │ (None, 13)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_48 (Dense)                     │ (None, 64)                  │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_49 (Dense)                     │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_50 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_51 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,169 (28.00 KB)
#  Trainable params: 7,169 (28.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2181.4429 - mae: 38.9133 - val_loss: 141.8833 - val_mae: 10.0411
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 187.6130 - mae: 10.9453 - val_loss: 103.4801 - val_mae: 7.0141
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 128.7917 - mae: 9.0026 - val_loss: 97.3153 - val_mae: 6.5198
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 102.7479 - mae: 7.1083 - val_loss: 95.2566 - val_mae: 7.7465
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 88.2654 - mae: 7.1342 - val_loss: 90.7128 - val_mae: 6.1297
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 72.0607 - mae: 6.0628 - val_loss: 76.6948 - val_mae: 6.3002
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 68.5245 - mae: 5.6752 - val_loss: 73.7299 - val_mae: 6.3778
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 58.8879 - mae: 5.4355 - val_loss: 77.6469 - val_mae: 5.6273
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 76.8412 - mae: 5.8344 - val_loss: 75.4303 - val_mae: 5.5548
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.0772 - mae: 5.2755 - val_loss: 70.4827 - val_mae: 6.0143
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 64.4991 - mae: 5.9075 - val_loss: 77.6518 - val_mae: 5.6011
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 84.8207 - mae: 6.7688 - val_loss: 95.2188 - val_mae: 6.3532
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.8990 - mae: 5.2941 - val_loss: 73.0118 - val_mae: 5.4620
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 62.3028 - mae: 5.2978 - val_loss: 81.9360 - val_mae: 7.4561
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 69.6639 - mae: 6.5275 - val_loss: 69.0318 - val_mae: 5.4424
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 47.8852 - mae: 4.9968 - val_loss: 71.7833 - val_mae: 5.3309
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 55.3567 - mae: 4.9606 - val_loss: 75.3809 - val_mae: 5.4334
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 66.8930 - mae: 5.1292 - val_loss: 79.4223 - val_mae: 5.6351
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 71.9996 - mae: 5.5258 - val_loss: 66.3512 - val_mae: 5.3182
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.1320 - mae: 5.2487 - val_loss: 70.3177 - val_mae: 5.2919
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: